# %%
import warnings
warnings.filterwarnings('ignore')
# %config Completer.use_jedi = False 
# helps to ignore the warning

# %%
import numpy as np
import pandas as pd

# %%
# !pip install text_hammer   # used to avoud the spelling correction
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting text_hammer
#   Downloading text_hammer-0.1.5-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from text_hammer) (1.3.5)
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (from text_hammer) (3.4.4)
# Requirement already satisfied: TextBlob in /usr/local/lib/python3.8/dist-packages (from text_hammer) (0.15.3)
# Collecting beautifulsoup4==4.9.1
#   Downloading beautifulsoup4-4.9.1-py3-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 14.5 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from text_hammer) (1.21.6)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->text_hammer) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->text_hammer) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->text_hammer) (1.15.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (0.10.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (1.0.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (0.7.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (2.23.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (2.0.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (57.4.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (2.4.5)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (1.0.4)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (8.1.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (2.11.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (2.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (6.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (3.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (1.10.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (3.0.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (4.64.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (0.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy->text_hammer) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy->text_hammer) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy->text_hammer) (4.4.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy->text_hammer) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy->text_hammer) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy->text_hammer) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy->text_hammer) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy->text_hammer) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy->text_hammer) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy->text_hammer) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy->text_hammer) (2.0.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.8/dist-packages (from TextBlob->text_hammer) (3.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->TextBlob->text_hammer) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk>=3.1->TextBlob->text_hammer) (2022.6.2)
# Installing collected packages: soupsieve, beautifulsoup4, text-hammer
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed beautifulsoup4-4.9.1 soupsieve-2.3.2.post1 text-hammer-0.1.5

# %%
import text_hammer as th

# %%
import seaborn as sns   # used to visualize the exploratory data

# %%
import matplotlib.pyplot as plt  # used to plot the data in graph

# %%
import re      # used for the regular expression

# %%
from wordcloud import STOPWORDS    # wordcloud is used to identify the specific words

# %%
from collections import defaultdict  # importing dictonary defaulty through the collection

# %%
from tqdm._tqdm_notebook import tqdm_notebook  # library is used to creating the progress bar

# %%
tqdm_notebook.pandas()  # where these notebook of tqdm uses pandas library

# %%
! pip install transformers  # installation of transformer in Bert Model
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 13.6 MB/s
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 56.4 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 77.3 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.25.1

# %%
from transformers import AutoTokenizer,TFBertModel   # transformer helps to automatic tokenizating for every significant words and uses the tensor flow model

# %%
max_len = 36   # fixing the maximum length as 36

# %%
import tensorflow as tf
tf.config.experimental.list_physical_devices('GPU')     # GPU is configured for tensorflow
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from tensorflow.keras.optimizers import Adam     # tensorflow based keras optimizer is used where adam acts as optimizer

# %%
from tensorflow.keras.callbacks import EarlyStopping     # for keras callbacks earlystopping is imported

# %%
from tensorflow.keras.initializers import TruncatedNormal   # trancated normal intializer is used to intialize

# %%
from tensorflow.keras.losses import CategoricalCrossentropy,BinaryCrossentropy   # losses are identified by using crossentropy and binary entropy

# %%
from tensorflow.keras.metrics import CategoricalAccuracy,BinaryAccuracy   # metrics are identified using accuracies

# %%
from tensorflow.keras.utils import to_categorical  # collection of small python function and class which makes common pattern and it is imported to categorical data

# %%
from tensorflow.keras.utils import plot_model  # used for plotting the model

# %%
from tensorflow.keras.layers import Input, Dense     #  Keras Dense layer that is regular deep connected layer

# %%
from nltk.corpus import stopwords    # nltk corpus library is used to stop the word while preprocessing
from wordcloud import WordCloud      # importing wordcloud to represent the stop word

# %%
from google.colab import drive
drive.mount('/content/drive')    # importing drive dataset in google colab
# Out:
# Mounted at /content/drive

# %%
train_data = pd.read_csv('/content/drive/MyDrive/Assam_tweets.csv')

# %%
train_data.head(25)   # trained with obtained features
# Out:
#         tweet_id  receiver_id  \
# 0   1.544307e+18          NaN
# 1   1.544307e+18          NaN
# 2   1.544307e+18          NaN
# 3   1.544307e+18          NaN
# 4   1.544307e+18          NaN
# 5   1.544307e+18          NaN
# 6   1.544307e+18          NaN
# 7   1.544307e+18          NaN
# 8   1.544307e+18          NaN
# 9   1.544307e+18          NaN
# 10  1.544307e+18          NaN
# 11  1.544307e+18          NaN
# 12  1.544307e+18          NaN
# 13  1.544307e+18          NaN
# 14  1.544307e+18          NaN
# 15  1.544307e+18          NaN
# 16  1.544307e+18          NaN
# 17  1.544307e+18          NaN
# 18  1.544307e+18          NaN
# 19  1.544307e+18          NaN
# 20  1.544307e+18          NaN
# 21  1.544307e+18          NaN
# 22  1.544307e+18          NaN
# 23  1.544307e+18          NaN
# 24  1.544307e+18          NaN
#
#                                            tweet_text  \
# 0   RT @zuckmetaverse: Kabul Khan, Mithu Hussain L...
# 1   RT @the_hindu: President #RamNathKovind called...
# 2   RT @RatanSharda55: While we are debating #Amra...
# 3   RT @AbhishBanerj: Why is this not biggest news...
# 4   RT @ErayCr: So, Assam floods—that claimed 170+...
# 5   RT @RatanSharda55: While we are debating #Amra...
# 6   RT @arunpudur: Assam : Kabul Khan, Mithu Hussa...
# 7   RT @ByRakeshSimha: Flood jehad\n\nAssam Police...
# 8   RT @AbhishBanerj: Why is this not biggest news...
# 9   RT @RatanSharda55: While we are debating #Amra...
# 10  RT @RatanSharda55: While we are debating #Amra...
# 11  RT @ShefVaidya: In last few weeks, #KanhaiyaLa...
# 12  RT @RashmiDVS: The man-made floods of Assam sh...
# 13  RT @RatanSharda55: While we are debating #Amra...
# 14  RT @AbhishBanerj: Why is this not biggest news...
# 15  RT @AbhishBanerj: Why is this not biggest news...
# 16  RT @ShefVaidya: In last few weeks, #KanhaiyaLa...
# 17  RT @arunpudur: Assam : Kabul Khan, Mithu Hussa...
# 18  RT @SimranB42671851: We all raised our voices ...
# 19  RT @RashmiDVS: The man-made floods of Assam sh...
# 20  RT @RashmiDVS: The man-made floods of Assam sh...
# 21  RT @AbhishBanerj: Why is this not biggest news...
# 22  RT @AbhishBanerj: Why is this not biggest news...
# 23  RT @AbhishBanerj: Why is this not biggest news...
# 24  RT @DharmsenaRDS: Assam floods were man made.....
#
#                     timestamp                     location  \
# 0   2022-07-05 13:08:07+00:00                          NaN
# 1   2022-07-05 13:08:07+00:00                          NaN
# 2   2022-07-05 13:08:06+00:00               Gujarat, India
# 3   2022-07-05 13:08:02+00:00                 Delhi, India
# 4   2022-07-05 13:08:01+00:00                          NaN
# 5   2022-07-05 13:07:54+00:00                       Bharat
# 6   2022-07-05 13:07:51+00:00                          NaN
# 7   2022-07-05 13:07:43+00:00                          NaN
# 8   2022-07-05 13:07:33+00:00                          NaN
# 9   2022-07-05 13:07:33+00:00                Raipur, India
# 10  2022-07-05 13:07:21+00:00                       Bharat
# 11  2022-07-05 13:07:09+00:00                          NaN
# 12  2022-07-05 13:06:54+00:00               Free Nummah !!
# 13  2022-07-05 13:06:50+00:00             Hyderabad, India
# 14  2022-07-05 13:06:48+00:00                  Pune, India
# 15  2022-07-05 13:06:47+00:00                          NaN
# 16  2022-07-05 13:06:46+00:00                          NaN
# 17  2022-07-05 13:06:39+00:00  Delhi, Bengaluru,  gurugram
# 18  2022-07-05 13:06:34+00:00                          NaN
# 19  2022-07-05 13:06:31+00:00                          NaN
# 20  2022-07-05 13:06:24+00:00                     Timbaktu
# 21  2022-07-05 13:06:23+00:00             Bangalore, India
# 22  2022-07-05 13:06:20+00:00                        India
# 23  2022-07-05 13:06:17+00:00                        India
# 24  2022-07-05 13:06:15+00:00      Edison, New Jersey, USG
#
#                            name  \
# 0            IndicRWFollower 🇮🇳
# 1                    MD Shahjad
# 2    બ્રિજેશ પટેલ Brijesh Patel
# 3                  Apoorv Tyagi
# 4                          anon
# 5                 Dubious crime
# 6                      1-2 Ka 4
# 7                   imshreeyash
# 8                 honeysonujain
# 9                         Arjun
# 10                        अवधूत
# 11  2004@GM TAMBRAM 3RD AVATAAR
# 12                          मनई
# 13             Santosh Kaluvala
# 14                   De-Stress🎷
# 15                         anon
# 16            Shivaani K Talwar
# 17               🇮🇳विनय कुमार 🚩
# 18     Deepshikha Bandyopadhyay
# 19                     predator
# 20                         Agni
# 21                  Yathish Raj
# 22         Pratijna Parayan Das
# 23                     TulsiDas
# 24                      Rishank
#
#                                              hashtags  \
# 0                                                  []
# 1    [{'text': 'RamNathKovind', 'indices': [25, 39]}]
# 2   [{'text': 'Amravati', 'indices': [41, 50]}, {'...
# 3                                                  []
# 4                                                  []
# 5   [{'text': 'Amravati', 'indices': [41, 50]}, {'...
# 6                                                  []
# 7                                                  []
# 8                                                  []
# 9   [{'text': 'Amravati', 'indices': [41, 50]}, {'...
# 10  [{'text': 'Amravati', 'indices': [41, 50]}, {'...
# 11  [{'text': 'KanhaiyaLal', 'indices': [35, 47]},...
# 12                                                 []
# 13  [{'text': 'Amravati', 'indices': [41, 50]}, {'...
# 14                                                 []
# 15                                                 []
# 16  [{'text': 'KanhaiyaLal', 'indices': [35, 47]},...
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22                                                 []
# 23                                                 []
# 24                                                 []
#
#                                         user_mentions
# 0   [{'screen_name': 'zuckmetaverse', 'name': 'Arj...
# 1   [{'screen_name': 'the_hindu', 'name': 'The Hin...
# 2   [{'screen_name': 'RatanSharda55', 'name': 'Rat...
# 3   [{'screen_name': 'AbhishBanerj', 'name': 'Abhi...
# 4   [{'screen_name': 'ErayCr', 'name': 'Eray Mridu...
# 5   [{'screen_name': 'RatanSharda55', 'name': 'Rat...
# 6   [{'screen_name': 'arunpudur', 'name': 'Arun Pu...
# 7   [{'screen_name': 'ByRakeshSimha', 'name': 'Rak...
# 8   [{'screen_name': 'AbhishBanerj', 'name': 'Abhi...
# 9   [{'screen_name': 'RatanSharda55', 'name': 'Rat...
# 10  [{'screen_name': 'RatanSharda55', 'name': 'Rat...
# 11  [{'screen_name': 'ShefVaidya', 'name': 'Shefal...
# 12  [{'screen_name': 'RashmiDVS', 'name': 'Rashmi ...
# 13  [{'screen_name': 'RatanSharda55', 'name': 'Rat...
# 14  [{'screen_name': 'AbhishBanerj', 'name': 'Abhi...
# 15  [{'screen_name': 'AbhishBanerj', 'name': 'Abhi...
# 16  [{'screen_name': 'ShefVaidya', 'name': 'Shefal...
# 17  [{'screen_name': 'arunpudur', 'name': 'Arun Pu...
# 18  [{'screen_name': 'SimranB42671851', 'name': 'S...
# 19  [{'screen_name': 'RashmiDVS', 'name': 'Rashmi ...
# 20  [{'screen_name': 'RashmiDVS', 'name': 'Rashmi ...
# 21  [{'screen_name': 'AbhishBanerj', 'name': 'Abhi...
# 22  [{'screen_name': 'AbhishBanerj', 'name': 'Abhi...
# 23  [{'screen_name': 'AbhishBanerj', 'name': 'Abhi...
# 24  [{'screen_name': 'DharmsenaRDS', 'name': 'Rash...

# %%
test_data  = pd.read_csv( '/content/drive/MyDrive/Test set of 2022- Assam twitterdata - Copy of 2022- Assam twitterdata.csv',usecols=['tweet_id', 'tweet_text','name'])

# %%
test_data.head(25)  # tweets to be tested without target value
# Out:
#                tweet_id                                         tweet_text  \
# 0   1541458926977581056  rt gurmeetramrahim saddened tragic loss life c...
# 1   1541458728603602945  rt gurmeetramrahim saddened tragic loss life c...
# 2   1541458682331922433  rt surendr04202886 humanityaimsofmsg dss volun...
# 3   1541458618582958080  rt surendr04202886 humanityaimsofmsg dss volun...
# 4   1541458372653748224  rt gurmeetramrahim saddened tragic loss life c...
# 5   1541457938262491137  rt gurmeetramrahim greens volunteers msg2 fans...
# 6   1541457871724253185  rt gurmeetramrahim saddened tragic loss life c...
# 7   1541457534544134144  rt gurmeetramrahim saddened tragic loss life c...
# 8   1541457281157677057  rt gurmeetramrahim saddened tragic loss life c...
# 9   1541457115746893830  rt gurmeetramrahim saddened tragic loss life c...
# 10  1541457089406435329  rt gurmeetramrahim saddened tragic loss life c...
# 11  1541457023518523392  rt gurmeetramrahim greens volunteers msg2 fans...
# 12  1541456921173331968  rt gurmeetramrahim greens volunteers reached c...
# 13  1541456914856325120  rt gurmeetramrahim saddened tragic loss life c...
# 14  1541456849924280320  rt gurmeetramrahim msg2in12thweek greens volun...
# 15  1541456838503596033  rt gurmeetramrahim greens volunteers msg2 fans...
# 16  1541456796359225344  rt gurmeetramrahim greens volunteers reached c...
# 17  1541456434499575808  rt gurmeetramrahim msg2in12thweek greens volun...
# 18  1541456335706787841  rt gurmeetramrahim greens volunteers msg2 fans...
# 19  1541456271865696256  rt gurmeetramrahim greens volunteers reached c...
# 20  1541456267796946949  rt gurmeetramrahim saddened tragic loss life c...
# 21  1541456116085039105  rt gurmeetramrahim greens volunteers reached c...
# 22  1541455995486208002  rt gurmeetramrahim greens volunteers reached c...
# 23  1541455575422476288  rt gurmeetramrahim msg2in12thweek greens volun...
# 24  1541455573157543936  rt gurmeetramrahim msg2in12thweek greens volun...
#
#                          name
# 0                  ConnectFor
# 1                 IDLE INDIAN
# 2        International Rivers
# 3              Aditya R Singh
# 4                       hifza
# 5                   Time2Rise
# 6                       Anu❣️
# 7              Business Today
# 8         EIon Mosk (Parody)
# 9   Sunil M. Caleb سنیل کا؛لب
# 10                An Observer
# 11        Clandestine Updates
# 12      RituBlueFairy ARM ऋतु
# 13                          🎀
# 14     Ritu Gupta ऋतु Hritu🇮🇳
# 15      RituBlueFairy ARM ऋतु
# 16      RituBlueFairy ARM ऋतु
# 17                Asif sayyad
# 18            IndiaTodayFLASH
# 19       Prashant Kumar Singh
# 20               Prabhasakshi
# 21                 IndiaToday
# 22        Nayak Rudra Narayan
# 23            IndiaTodayFLASH
# 24              Gopal Agarwal

# %%
# After Feature selected  then next stage preprocessing the data
def text_preprocessing(df,col_name):   # defining the text preprocessing with column name
    column = col_name
    df[column] = df[column].progress_apply(lambda x:str(x).lower())  # defining the specified columns with lower case
    df[column] = df[column].progress_apply(lambda x: th.remove_emails(x))   # helps to remove the email id
    df[column] = df[column].progress_apply(lambda x: th.remove_html_tags(x))   # helps to remove the htmal tags
    df[column] = df[column].progress_apply(lambda x: th.remove_special_chars(x))  # helps to remove the special characters
    df[column] = df[column].progress_apply(lambda x: th.remove_accented_chars(x)) # helps to remove the shortcut keywords
    return(df)

# %%
train_cleaned_data = text_preprocessing(train_data,'tweet_text')   # above mentioned preprocessing steps are implemented to specific coloum 'tweettext' from the train dataset
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]
#   0%|          | 0/20000 [00:00<?, ?it/s]
#   0%|          | 0/20000 [00:00<?, ?it/s]
#   0%|          | 0/20000 [00:00<?, ?it/s]
#   0%|          | 0/20000 [00:00<?, ?it/s]

# %%
train_data = train_cleaned_data.copy()
train_data.head (5)
# Out:
#        tweet_id  receiver_id  \
# 0  1.544307e+18          NaN
# 1  1.544307e+18          NaN
# 2  1.544307e+18          NaN
# 3  1.544307e+18          NaN
# 4  1.544307e+18          NaN
#
#                                           tweet_text  \
# 0  rt zuckmetaverse kabul khan mithu hussain lask...
# 1  rt the_hindu president ramnathkovind called as...
# 2  rt ratansharda55 while we are debating amravat...
# 3  rt abhishbanerj why is this not biggest news i...
# 4  rt eraycr so assam floodsthat claimed 170 live...
#
#                    timestamp        location                        name  \
# 0  2022-07-05 13:08:07+00:00             NaN          IndicRWFollower 🇮🇳
# 1  2022-07-05 13:08:07+00:00             NaN                  MD Shahjad
# 2  2022-07-05 13:08:06+00:00  Gujarat, India  બ્રિજેશ પટેલ Brijesh Patel
# 3  2022-07-05 13:08:02+00:00    Delhi, India                Apoorv Tyagi
# 4  2022-07-05 13:08:01+00:00             NaN                        anon
#
#                                             hashtags  \
# 0                                                 []
# 1   [{'text': 'RamNathKovind', 'indices': [25, 39]}]
# 2  [{'text': 'Amravati', 'indices': [41, 50]}, {'...
# 3                                                 []
# 4                                                 []
#
#                                        user_mentions
# 0  [{'screen_name': 'zuckmetaverse', 'name': 'Arj...
# 1  [{'screen_name': 'the_hindu', 'name': 'The Hin...
# 2  [{'screen_name': 'RatanSharda55', 'name': 'Rat...
# 3  [{'screen_name': 'AbhishBanerj', 'name': 'Abhi...
# 4  [{'screen_name': 'ErayCr', 'name': 'Eray Mridu...
