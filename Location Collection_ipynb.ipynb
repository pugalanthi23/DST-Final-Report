# %%
import nltk
import spacy

# essential entity models downloads
nltk.downloader.download('maxent_ne_chunker')
nltk.downloader.download('words')
nltk.downloader.download('treebank')
nltk.downloader.download('maxent_treebank_pos_tagger')
nltk.downloader.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.
# [nltk_data] Downloading package maxent_treebank_pos_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
# !pip install locationtagger
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting locationtagger
#   Downloading locationtagger-0.0.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 4.9 MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from locationtagger) (3.7)
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#      |████████████████████████████████| 211 kB 42.4 MB/s
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (from locationtagger) (3.3.1)
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      |████████████████████████████████| 10.1 MB 38.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from newspaper3k->locationtagger) (2.23.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from newspaper3k->locationtagger) (4.6.3)
# Collecting cssselect>=0.9.2
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from newspaper3k->locationtagger) (2.8.2)
# Collecting tinysegmenter==0.3
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
# Collecting feedparser>=5.2.1
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 8.4 MB/s
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from newspaper3k->locationtagger) (4.2.6)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.7/dist-packages (from newspaper3k->locationtagger) (3.13)
# Collecting tldextract>=2.0.1
#   Downloading tldextract-3.3.0-py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 1.9 MB/s
# Collecting jieba3k>=0.35.1
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      |████████████████████████████████| 7.4 MB 32.1 MB/s
# Collecting feedfinder2>=0.0.4
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.7/dist-packages (from newspaper3k->locationtagger) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from feedfinder2>=0.0.4->newspaper3k->locationtagger) (1.15.0)
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->locationtagger) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk->locationtagger) (4.64.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk->locationtagger) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->locationtagger) (1.1.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->newspaper3k->locationtagger) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->newspaper3k->locationtagger) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->newspaper3k->locationtagger) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->newspaper3k->locationtagger) (2022.6.15)
# Collecting requests-file>=1.4
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from tldextract>=2.0.1->newspaper3k->locationtagger) (3.7.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pycountry->locationtagger) (57.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (1.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (1.21.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (2.4.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (0.4.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (8.0.17)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (1.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (2.11.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (0.7.7)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (4.1.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (0.9.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (2.0.7)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (0.6.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (3.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (21.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (1.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (3.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy->locationtagger) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy->locationtagger) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy->locationtagger) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy->locationtagger) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy->locationtagger) (2.0.1)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k, pycountry, sgmllib3k
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13553 sha256=7a9dac11c7b1c8c9ed8029a963acecda44cb6084b587ef27e14ac0377cdee616
#   Stored in directory: /root/.cache/pip/wheels/df/67/41/faca10fa501ca010be41b49d40360c2959e1c4f09bcbfa37fa
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3357 sha256=34e59e648868045f8b50bc177f2ab2f4e96708bf6b15e35e4e6194758fca2805
#   Stored in directory: /root/.cache/pip/wheels/7f/d4/8f/6e2ca54744c9d7292d88ddb8d42876bcdab5e6d84a21c10346
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398404 sha256=f9c08d6bf8698ec7b1c0dbc911f5e3c090c601fce8986c0bfe8cb3448aef343e
#   Stored in directory: /root/.cache/pip/wheels/4c/91/46/3c208287b726df325a5979574324878b679116e4baae1af3c3
#   Building wheel for pycountry (PEP 517) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681845 sha256=acefba65787bc04ab651a94ecf0f07a79372f50c700a43ce17594602cf75eb18
#   Stored in directory: /root/.cache/pip/wheels/0e/06/e8/7ee176e95ea9a8a8c3b3afcb1869f20adbd42413d4611c6eb4
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=192891f2779fe1a1817207531271782b893d1456bde1e1122c03fafd086115cd
#   Stored in directory: /root/.cache/pip/wheels/73/ad/a4/0dff4a6ef231fc0dfa12ffbac2a36cebfdddfe059f50e019aa
# Successfully built tinysegmenter feedfinder2 jieba3k pycountry sgmllib3k
# Installing collected packages: sgmllib3k, requests-file, tldextract, tinysegmenter, jieba3k, feedparser, feedfinder2, cssselect, pycountry, newspaper3k, locationtagger
# Successfully installed cssselect-1.1.0 feedfinder2-0.0.4 feedparser-6.0.10 jieba3k-0.35.1 locationtagger-0.0.1 newspaper3k-0.2.8 pycountry-22.3.5 requests-file-1.5.1 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-3.3.0

# %%
import locationtagger

# %%
sp = spacy.load("en_core_web_sm")
# loop over every row in the 'Bio' column
for text in train_data['tweet_text'].tolist():
    # use spacy to extract the entities
    doc = sp(text)
    for ent in doc.ents:
        # check if entity is equal 'LOC' or 'GPE'
        if ent.label_ in ['LOC', 'GPE']:
            print(ent.text, ent.label_)
# Out:
# Assam GPE
# @DG_NTA GPE
# Assam GPE
# India GPE
# Assam GPE
# Assam GPE
# @LevinaNeythiri States GPE
# Assam GPE
# Odisha GPE
# Assam GPE
# @DG_NTA GPE
# @DG_NTA GPE
# Assam @SonuSood GPE
# india GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# নষ্ট GPE
# @DG_NTA GPE
# India GPE
# Majuli GPE
# Assam GPE
# Assam GPE
# @DG_NTA GPE
# Assam GPE
# india GPE
# Kurichu GPE
# Assam GPE
# Assam GPE
# Assam GPE
# @DG_NTA GPE
# की मौत GPE
# @DG_NTA GPE
# Assam GPE
# Assam GPE
# @DG_NTA GPE
# @DG_NTA GPE
# Assam GPE
# Assam GPE
# Oxfam India LOC
# @UNICEFIndia GPE
# Silchar LOC
# South Assam’s GPE
# Bihar GPE
# Assam @SonuSood GPE
# Delhi GPE
# Mumbai GPE
# North East Ind LOC
# Delhi GPE
# Mumbai GPE
# North East Ind LOC
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam @SonuSood GPE
# Barak Valley GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Delhi GPE
# Mumbai GPE
# North East Ind LOC
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Delhi GPE
# Mumbai GPE
# North East Ind LOC
# Assam GPE
# North East Flood LOC
# Delhi GPE
# Mumbai GPE
# North East Ind LOC
# Delhi GPE
# Mumbai GPE
# North East Ind LOC
# Barak Valley GPE
# @DG_NTA GPE
# रेल GPE
# Kurichu GPE
# Assam GPE
# @DG_NTA GPE
# Assam GPE
# Silchar GPE
# Kannan GPE
# Assam GPE
# Kurichu GPE
# Assam GPE
# North East Flood LOC
# Assam GPE
# India GPE
# @DG_NTA GPE
# @DG_NTA GPE
# Assam GPE
# Assam GPE
# Assam GPE
# India GPE
# India GPE
# https://t.co/lzHGtptyPW https://t.co/G GPE
# बारिश GPE
# बाढ़ GPE
# Assam GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# Silchar GPE
# India GPE
# https://t.co/lzHGtptyPW https://t.co/G GPE
# India GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Barak Valley GPE
# Silchar GPE
# Kannan GPE
# Barak Valley GPE
# बाढ़ के GPE
# @DG_NTA GPE
# बाढ़ के GPE
# Assam GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# Assam GPE
# Assam GPE
# @DG_NTA GPE
# @DG_NTA GPE
# Assam @SonuSood GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Moina GPE
# @DG_NTA GPE
# Assam GPE
# Assam GPE
# Tripura GPE
# Meghalaya GPE
# @DG_NTA GPE
# @DG_NTA GPE
# Assam GPE
# Assam GPE
# @DG_NTA GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# @DG_NTA GPE
# Silchar GPE
# Assam @SonuSood GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# Assam GPE
# @DG_NTA GPE
# Silchar GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# Assam GPE
# Assam GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# Assam GPE
# Assam GPE
# Assam GPE
# https://t.co/1lBnRtTGnS GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# Trail GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# @DG_NTA GPE
# Delhi GPE
# Mumbai GPE
# North East Ind LOC
# Silchar GPE
# India GPE
# https://t.co/lzHGtptyPW https://t.co/G GPE
# Bajali GPE
# india GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Delhi GPE
# Mumbai GPE
# North East Ind LOC
# Assam GPE
# Assam GPE
# Assam GPE
# Assam @SonuSood GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam @SonuSood GPE
# Bihar GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Mumbai GPE
# India GPE
# Assam GPE
# Assam GPE
# India GPE
# Assam GPE
# Assam GPE
# Assam GPE
# https://t.co/hyJVDiIZTj GPE
# Assam GPE
# Silchar GPE
# Assam @SonuSood GPE
# Assam GPE
# Assam GPE
# Silchar GPE
# Assam GPE
# Assam GPE
# India GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam @SonuSood GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Silchar GPE
# Delhi GPE
# Mumbai GPE
# North East Ind LOC
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam @SonuSood GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam @SonuSood GPE
# Assam GPE
# Assam GPE
# Mumbai GPE
# India GPE
# Assam GPE
# Assam GPE
# Oxfam India LOC
# @UNICEFIndia GPE
# Silchar LOC
# South Assam’s GPE
# Assam GPE
# India GPE
# https://t.co/lzHGtptyPW https://t.co/G GPE
# Mumbai GPE
# India GPE
# India GPE
# https://t.co/lzHGtptyPW https://t.co/G GPE
# Assam @SonuSood GPE
# Assam GPE
# Assam GPE
# India GPE
# Assam GPE
# Assam GPE
# Assam @SonuSood GPE
# Silchar GPE
# Assam GPE
# Assam GPE
# India GPE
# Assam GPE
# India GPE
# Assam GPE
# Assam GPE
# Assam @SonuSood GPE
# Assam @SonuSood GPE
# Assam GPE
# Assam GPE
# the southwest monsoon LOC
# Assam GPE
# Assam GPE
# Assam Rifles GPE
# @UNICEFIndia GPE
# Mumbai GPE
# India GPE
# Silchar LOC
# Assam GPE
# Assam GPE
# India GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Delhi GPE
# Mumbai GPE
# North East Ind LOC
# India GPE
# https://t.co/lzHGtptyPW https://t.co/G GPE
# Assam @SonuSood GPE
# Assam GPE
# Assam GPE
# Delhi GPE
# Mumbai GPE
# North East Ind LOC
# Assam GPE
# India GPE
# India GPE
# Assam GPE
# India GPE
# Silchar LOC
# Assam GPE
# Assam GPE
# Assam GPE
# Silchar LOC
# Assam GPE
# Delhi GPE
# Mumbai GPE
# North East Ind LOC
# Assam GPE
# Silchar LOC
# Assam GPE
# India GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Trail GPE
# Silchar LOC
# Assam GPE
# Delhi GPE
# Mumbai GPE
# North East Ind LOC
# https://t.co/EO5xwWy4L3 GPE
# Silchar LOC
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Mumbai GPE
# India GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# India GPE
# https://t.co/lzHGtptyPW https://t.co/G GPE
# Mumbai GPE
# India GPE
# Assam GPE
# India GPE
# Assam GPE
# humong GPE
# Bollywood GPE
# Silchar LOC
# Assam GPE
# Assam GPE
# India GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Silchar GPE
# Silchar GPE
# Assam GPE
# Assam GPE
# India GPE
# https://t.co/lzHGtptyPW https://t.co/G GPE
# India GPE
# Assam GPE
# Assam GPE
# India GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Germany GPE
# India GPE
# Mumbai GPE
# India GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam @SonuSood GPE
# Silchar GPE
# Assam @SonuSood GPE
# Didi GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# India GPE
# Assam GPE
# India GPE
# https://t.co/lzHGtptyPW https://t.co/G GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam @SonuSood GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Mahara GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Tripura GPE
# Meghalaya GPE
# Assam GPE
# India GPE
# Assam GPE
# India GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam GPE
# Assam @SonuSood GPE
# Assam @SonuSood GPE
# Assam @SonuSood GPE
# Assam @SonuSood GPE
# Assam @SonuSood GPE
# India GPE
# India GPE
# Assam @SonuSood GPE
# India GPE
# Assam GPE
# Assam GPE
# Silchar LOC
# India GPE
# Lutyens GPE
# Assam GPE
# Assam @SonuSood GPE
# India GPE
# India GPE
# India GPE
# India GPE
# India GPE
# India GPE
# India GPE
# Assam GPE
# India GPE
# https://t.co/lzHGtptyPW https://t.co/G GPE
# Assam GPE
# Tripura GPE
# Meghalaya GPE
# India GPE
# https://t.co/lzHGtptyPW https://t.co/G GPE
# Trail GPE
